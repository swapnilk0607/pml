# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = plt.imread('../data/penguins.png')

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (370, 370, 4)

# %%
plt.imshow(a);

# %% [markdown]
# - `imread`  returns an array of shape (370, 370, 4) which represents an
#   image of 370x370 pixels and 4 channels.
# - The 4 channels represent R, G, B, Alpha
# - `imshow`  renders the array as an image.

# %% [markdown]
# Instead of using matplotlib's imread which is limited, one can use
# [imageio](https://imageio.github.io)

# %%
import imageio
a = imageio.imread("../data/penguins.png")
# Out:
# C:\Users\SUSHANT\AppData\Local\Temp\ipykernel_28528\3790379149.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   a = imageio.imread("../data/penguins.png")

# %%
plt.imshow(a);

# %% [markdown]
# ### Showing the different channels of the image.
#
# ### Exercise
# - Extract the red channel of the image and show it.

# %%
a[:, :, 3].shape
# Out:
# (370, 370)

# %%
# Solution
# plt.imshow(a[:,:, 0]);
x = np.random.random((3, 3))
print(x)
plt.imshow(x);
plt.colorbar();
# Out:
# [[0.7874348  0.19226805 0.30105709]
#  [0.49363443 0.9016686  0.52403534]
#  [0.11994848 0.38770179 0.01777015]]

# %% [markdown]
# ### How can we see things in different colors?
#
# - Matplotlib provides a ton of different colormaps
# - First let us understand what a colormap is.
# - Read more in the matplotlib docs here: https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %%
print(list(plt.colormaps))
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'berlin', 'managua', 'vanimo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'berlin_r', 'managua_r', 'vanimo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 'Greens_r', 'Greys_r', 'OrRd_r', 'Oranges_r', 'PRGn_r', 'PiYG_r', 'PuBu_r', 'PuBuGn_r', 'PuOr_r', 'PuRd_r', 'Purples_r', 'RdBu_r', 'RdGy_r', 'RdPu_r', 'RdYlBu_r', 'RdYlGn_r', 'Reds_r', 'Spectral_r', 'Wistia_r', 'YlGn_r', 'YlGnBu_r', 'YlOrBr_r', 'YlOrRd_r', 'afmhot_r', 'autumn_r', 'binary_r', 'bone_r', 'brg_r', 'bwr_r', 'cool_r', 'coolwarm_r', 'copper_r', 'cubehelix_r', 'flag_r', 'gist_earth_r', 'gist_gray_r', 'gist_heat_r', 'gist_ncar_r', 'gist_rainbow_r', 'gist_stern_r', 'gist_yarg_r', 'gnuplot_r', 'gnuplot2_r', 'gray_r', 'hot_r', 'hsv_r', 'jet_r', 'nipy_spectral_r', 'ocean_r', 'pink_r', 'prism_r', 'rainbow_r', 'seismic_r', 'spring_r', 'summer_r', 'terrain_r', 'winter_r', 'Accent_r', 'Dark2_r', 'Paired_r', 'Pastel1_r', 'Pastel2_r', 'Set1_r', 'Set2_r', 'Set3_r', 'tab10_r', 'tab20_r', 'tab20b_r', 'tab20c_r', 'grey_r', 'gist_grey_r', 'gist_yerg_r', 'Grays_r']

# %%
plt.imshow(a[:, :, 0], cmap='Reds');
plt.colorbar();

# %% [markdown]
# ### Showing all the different channels?
#
# - Use subplots

# %%
plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.imshow(a)
plt.colorbar();
plt.subplot(2, 2, 2)
plt.imshow(a[:, :, 0], cmap='Reds')
plt.colorbar();
plt.subplot(2, 2, 3)
plt.imshow(a[..., 1], cmap='Greens')  # Notice the use of ellipsis
plt.colorbar();
plt.subplot(2, 2, 4)
plt.imshow(a[..., 2], cmap='Blues')
plt.colorbar();

# %% [markdown]
# ### Showing a histogram of the red channel
#
# - Cannot blindly use `plt.hist` as the array is not 1D
# - We have to "ravel" or "flatten" it.

# %%
plt.hist(a[..., 0].flat, bins='auto', color='red');

# %%
plt.hist(a[..., 2].ravel(), bins='auto');

# %% [markdown]
# ### Exercise
#
# Make a histogram for each of the 4 channels and plot these in a single
# figure with subplots.

# %%
plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.hist(a[..., 0].ravel(), bins='auto', color='red');

plt.subplot(2, 2, 2)
plt.hist(a[..., 1].flat, bins='auto', color='g');

plt.subplot(2, 2, 3)
plt.hist(a[..., 2].flat, bins='auto', color='b');

plt.subplot(2, 2, 4)
plt.hist(a[..., 3].flat, bins='auto', color='y');

# %% [markdown]
# ### Slicing and Striding Exercises
#
# * Crop the penguin image to get the top-left quarter
#
# * Crop the image to get only the face of the baby penguin
#
# * Resize image to half by dropping alternate pixels

# %%
# Solution
plt.imshow(a[:, :]);

plt.figure(figsize=(5, 5))
plt.subplot(2, 2, 1)
plt.imshow(a[:185, :185]);

plt.subplot(2, 2, 2)
plt.imshow(a[:185, 185:]);

plt.subplot(2, 2, 3)
plt.imshow(a[185:,:185]);

plt.subplot(2, 2, 4)
plt.imshow(a[185:,185:]);

# %%
plt.imshow(a[230:280,170:220]);

# %%
plt.imshow(a[::2, ::2]); # Taking every alternate pixels
