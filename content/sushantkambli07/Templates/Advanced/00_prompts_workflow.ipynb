# %% [markdown]
# ### Prompts

# %%
"""
- Create dataframe df from the file linear-data-set-for-regression.csv
- It contains y and one or more x columns. Find them out. Do the following:
  - Create a function sklearn_regression using a scikit-learn regression function and return the model.
  - Create a function OLS_regression, print the standard output generated, and return the model.
  - Create a function do_regression_analysis to take in df and do the following:
    - Split the data into train and test.
    - Call the sklearn_regression function and OLS_regression function and, after each, do the following:
      - Print out R², MAE, RMSE.
      - For both test and train data, plot the charts below:
        - Predicted Y and actual Y vs the first X variable
        - Test and train residuals vs the first X variable
        - Residuals vs X
        - Histogram of residuals
        - QQ-plot of residuals
      - Plots should be arranged 2 per row.
"""
# Out:
# '\n- Create dataframe df from the file linear-data-set-for-regression.csv\n- It contains y and one or more x columns. Find them out. Do the following:\n  - Create a function sklearn_regression using a scikit-learn regression function and return the model.\n  - Create a function OLS_regression, print the standard output generated, and return the model.\n  - Create a function do_regression_analysis to take in df and do the following:\n    - Split the data into train and test.\n    - Call the sklearn_regression function and OLS_regression function and, after each, do the following:\n      - Print out R², MAE, RMSE.\n      - For both test and train data, plot the charts below:\n        - Predicted Y and actual Y vs the first X variable\n        - Test and train residuals vs the first X variable\n        - Residuals vs X\n        - Histogram of residuals\n        - QQ-plot of residuals\n      - Plots should be arranged 2 per row.\n'

# %% [markdown]
# # WorkFlow -> Regression

# %%
""" 
0. Analyze the dataset first using excel with scatter plots, trendlines, etc. to get an idea of the relationships.

--- classify the problem as regression or classification ---

1. To Understand data generate the following plots:(use seaborn sns)
    - Histograms
    - Boxplots
    - Pairplots
    - Correlation Heatmap
    
2. Data Preprocessing:
    - Handle missing values + Imputation ?? which technique to use?
    - Outlier detection and treatment
    - Encode categorical variables
    - Apply transformation first before scaling. Transformations if needed to address skewed data(log... etc.)
    --- when to use standard scaler vs robust scaler vs minmax scaler ?? ---
    - Feature scaling and normalization or robust scaling  --> fit_transform on train and transform on test
    
3. Handle data imbalance if any using techniques like SMOTE, SMOTE+ENN, etc. random oversampling/undersampling.

4. Check for multicollinearity using VIF and correlation matrix.
    - Remove highly correlated features if necessary.
    - PCA if needed.
    - T-SNE for visualization if needed.
    
5. Model Selection and Training:
    - Split the dataset into training and testing sets
    - Choose appropriate algorithms based on the problem type (classification/regression)
    
"""

# %% [markdown]
# # Workflow -> Classification

# %%
""" 
0. Analyze the dataset first using excel with scatter plots, trendlines, etc. to get an idea of the relationships.

--- classify the problem as regression or classification ---

1. To Understand data generate the following plots:(use seaborn sns)
    - Histograms
    - Boxplots
    - Pairplots
    - Correlation Heatmap
    
2. Data Preprocessing:
    - Handle missing values + Imputation ?? which technique to use?
    - Outlier detection and treatment
    - Encode categorical variables
    - Apply transformation first before scaling. Transformations if needed to address skewed data(log... etc.)
    --- when to use standard scaler vs robust scaler vs minmax scaler ?? ---
    - Feature scaling and normalization or robust scaling  --> fit_transform on train and transform on test
    
3. Handle data imbalance if any using techniques like SMOTE, SMOTE+ENN, etc. random oversampling/undersampling.

4. Check for multicollinearity using VIF and correlation matrix.
    - Remove highly correlated features if necessary.
    - PCA if needed.
    - T-SNE for visualization if needed.
    
5. Model Selection and Training:
    - Split the dataset into training and testing sets
    - Choose appropriate algorithms based on the problem type (classification/regression)
    
"""

# %% [markdown]
# # Workflow --> NLP Text Processing

# %%
""" 
0. Analyze the dataset first using excel with scatter plots, trendlines, etc. to get an idea of the relationships.

--- classify the problem as regression or classification ---

1. To Understand data generate the following plots:(use seaborn sns)
    - Histograms
    - Boxplots
    - Pairplots
    - Correlation Heatmap
    
2. Data Preprocessing:
    - Handle missing values + Imputation ?? which technique to use?
    - Outlier detection and treatment
    - Encode categorical variables
    - Apply transformation first before scaling. Transformations if needed to address skewed data(log... etc.)
    --- when to use standard scaler vs robust scaler vs minmax scaler ?? ---
    - Feature scaling and normalization or robust scaling  --> fit_transform on train and transform on test
    
3. Handle data imbalance if any using techniques like SMOTE, SMOTE+ENN, etc. random oversampling/undersampling.

4. Check for multicollinearity using VIF and correlation matrix.
    - Remove highly correlated features if necessary.
    - PCA if needed.
    - T-SNE for visualization if needed.
    
5. Model Selection and Training:
    - Split the dataset into training and testing sets
    - Choose appropriate algorithms based on the problem type (classification/regression)
    
"""
